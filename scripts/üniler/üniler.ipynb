# %%
import pandas as pd

# CSV veya txt dosyanız varsa
df = pd.read_csv(r"C:\Users\E-SPOR\Desktop\egitim2\egitim2\scripts\üniler\eleman_bolumler_modified.csv")

# %%
df.shape
# Out:
# (66264, 8)

# %%
df.columns
# Out:
# Index(['bolum', 'universite', 'yil', 'siralama', 'puan', 'kontenjan',
#        'yop_kodu', 'puan_turu'],
#       dtype='object')

# %%
df.columns = [
    "Bölüm", "Üniversite", "Yıl", "Sıralama", "TabanPuan", 
    "Kontenjan", "UniKodu", "PuanTürü"
]

# %%
df
# Out:
#                                                    Bölüm  \
# 0          Ortopedik Protez ve Ortez Taban Puanları 2025
# 1          Ortopedik Protez ve Ortez Taban Puanları 2025
# 2          Ortopedik Protez ve Ortez Taban Puanları 2025
# 3          Ortopedik Protez ve Ortez Taban Puanları 2025
# 4          Ortopedik Protez ve Ortez Taban Puanları 2025
# ...                                                  ...
# 66259  Gıda Kalite Kontrolü ve Analizi Taban Puanları...
# 66260            Basım Teknolojileri Taban Puanları 2025
# 66261            Basım Teknolojileri Taban Puanları 2025
# 66262            Basım Teknolojileri Taban Puanları 2025
# 66263            Basım Teknolojileri Taban Puanları 2025
#
#                                               Üniversite   Yıl   Sıralama  \
# 0      Acıbadem Mehmet Ali Aydınlar Üniversitesi (%50...  2024  2.412.795
# 1      Acıbadem Mehmet Ali Aydınlar Üniversitesi (%50...  2023  2.321.281
# ...

# %%
# Yalnızca önemli sütunları pivotlamak
df_wide = df.pivot_table(
    index=["Bölüm", "Üniversite", "UniKodu", "PuanTürü"], 
    columns="Yıl",
    values=["Sıralama", "TabanPuan", "Kontenjan"],
    aggfunc='first'  # Aynı hücrede birden fazla değer varsa ilkini al
)

# Kolon isimlerini düzleştirelim
df_wide.columns = [f"{val}_{col}" for val, col in df_wide.columns]
df_wide = df_wide.reset_index()

# %%
df_wide
# Out:
#                                                    Bölüm  \
# 0            Abaza Dili ve Edebiyatı Taban Puanları 2025
# 1      Acil Durum ve Afet Yönetimi (Açıköğretim) Taba...
# 2      Acil Durum ve Afet Yönetimi (Açıköğretim) Taba...
# 3        Acil Durum ve Afet Yönetimi Taban Puanları 2025
# 4        Acil Durum ve Afet Yönetimi Taban Puanları 2025
# ...                                                  ...
# 21311        Şehir ve Bölge Planlama Taban Puanları 2025
# 21312        Şehir ve Bölge Planlama Taban Puanları 2025
# 21313        Şehir ve Bölge Planlama Taban Puanları 2025
# 21314        Şehir ve Bölge Planlama Taban Puanları 2025
# 21315        Şehir ve Bölge Planlama Taban Puanları 2025
#
#                              Üniversite    UniKodu PuanTürü Kontenjan_2021  \
# 0                    Düzce Üniversitesi  103390230      SOZ            ---
# 1                  Anadolu Üniversitesi  101051376      TYT            NaN
# ...

# %%
df_wide_sorted = df_wide.sort_values(by="TabanPuan_2024", ascending=False)
df_wide_sorted
# Out:
#                                              Bölüm  \
# 16267                      Tıp Taban Puanları 2025
# 16379                      Tıp Taban Puanları 2025
# 1854   Bilgisayar Mühendisliği Taban Puanları 2025
# 16181                      Tıp Taban Puanları 2025
# 5922                     Fizik Taban Puanları 2025
# ...                                            ...
# 17885       Çevre Mühendisliği Taban Puanları 2025
# 17875       Çevre Mühendisliği Taban Puanları 2025
# 17872       Çevre Mühendisliği Taban Puanları 2025
# 17871       Çevre Mühendisliği Taban Puanları 2025
# 13460           Siyaset Bilimi Taban Puanları 2025
#
#                                               Üniversite    UniKodu PuanTürü  \
# 16267                          Koç Üniversitesi (Burslu)  203910699      SAY
# 16379             İstanbul Medipol Üniversitesi (Burslu)  203110477      SAY
# 1854                           Koç Üniversitesi (Burslu)  203910363      SAY
# ...

# %%
df_wide_sorted['Bölüm'] = df_wide_sorted['Bölüm'].str.replace('Taban Puanları 2025','')
df_wide_sorted
# Out:
#                           Bölüm  \
# 16267                      Tıp
# 16379                      Tıp
# 1854   Bilgisayar Mühendisliği
# 16181                      Tıp
# 5922                     Fizik
# ...                         ...
# 17885       Çevre Mühendisliği
# 17875       Çevre Mühendisliği
# 17872       Çevre Mühendisliği
# 17871       Çevre Mühendisliği
# 13460           Siyaset Bilimi
#
#                                               Üniversite    UniKodu PuanTürü  \
# 16267                          Koç Üniversitesi (Burslu)  203910699      SAY
# 16379             İstanbul Medipol Üniversitesi (Burslu)  203110477      SAY
# 1854                           Koç Üniversitesi (Burslu)  203910363      SAY
# 16181  Acıbadem Mehmet Ali Aydınlar Üniversitesi (Bur...  200110071      SAY
# 5922                           Koç Üniversitesi (Burslu)  203910054      SAY
# ...                                                  ...        ...      ...
# ...

# %%
# ilk 2000 satırı al
df_wide_sorted = df_wide_sorted.head(2000)

# %%
df_wide_sorted2.to_json(r"C:\Users\E-SPOR\Desktop\egitim2\egitim2\scripts\üniler\üniler.json", orient='records', force_ascii=False)

# %%
for col in df_wide_sorted.columns:
    print(col)
# Out:
# Bölüm
# Üniversite
# UniKodu
# PuanTürü
# Kontenjan_2021
# Kontenjan_2022
# Kontenjan_2023
# Kontenjan_2024
# Sıralama_2021
# Sıralama_2022
# Sıralama_2023
# Sıralama_2024
# TabanPuan_2021
# TabanPuan_2022
# TabanPuan_2023
# TabanPuan_2024

# %%
df_wide_sorted['TabanPuan_2021'] = df_wide_sorted['TabanPuan_2021'].str.replace(',', '.')
df_wide_sorted['TabanPuan_2022'] = df_wide_sorted['TabanPuan_2022'].str.replace(',', '.')
df_wide_sorted['TabanPuan_2023'] = df_wide_sorted['TabanPuan_2023'].str.replace(',', '.')
df_wide_sorted['TabanPuan_2024'] = df_wide_sorted['TabanPuan_2024'].str.replace(',', '.')
# Out:
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\4274607063.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted['TabanPuan_2021'] = df_wide_sorted['TabanPuan_2021'].str.replace(',', '.')
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\4274607063.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted['TabanPuan_2022'] = df_wide_sorted['TabanPuan_2022'].str.replace(',', '.')
# ...

# %%
df_wide_sorted['TabanPuan_2021'] = df_wide_sorted['TabanPuan_2021'].astype(float)
df_wide_sorted['TabanPuan_2022'] = df_wide_sorted['TabanPuan_2022'].astype(float)
df_wide_sorted['TabanPuan_2023'] = df_wide_sorted['TabanPuan_2023'].astype(float)
df_wide_sorted['TabanPuan_2024'] = df_wide_sorted['TabanPuan_2024'].astype(float)
# Out:
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\3196380704.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted['TabanPuan_2021'] = df_wide_sorted['TabanPuan_2021'].astype(float)
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\3196380704.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted['TabanPuan_2022'] = df_wide_sorted['TabanPuan_2022'].astype(float)
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\3196380704.py:3: SettingWithCopyWarning:
# ...

# %%
df_wide_sorted['Sıralama_2021'] = df_wide_sorted['Sıralama_2021'].str.replace('.','')
df_wide_sorted['Sıralama_2022'] = df_wide_sorted['Sıralama_2022'].str.replace('.','')
df_wide_sorted['Sıralama_2023'] = df_wide_sorted['Sıralama_2023'].str.replace('.','')
df_wide_sorted['Sıralama_2024'] = df_wide_sorted['Sıralama_2024'].str.replace('.','')
# Out:
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\3588935590.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted['Sıralama_2021'] = df_wide_sorted['Sıralama_2021'].str.replace('.','')
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\3588935590.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted['Sıralama_2022'] = df_wide_sorted['Sıralama_2022'].str.replace('.','')
# ...

# %%
df_wide_sorted.fillna(0,inplace=True)
# Out:
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\3668438256.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted.fillna(0,inplace=True)

# %%
df_wide_sorted['Sıralama_2021'] = df_wide_sorted['Sıralama_2021'].astype(int)
df_wide_sorted['Sıralama_2022'] = df_wide_sorted['Sıralama_2022'].astype(int)
df_wide_sorted['Sıralama_2023'] = df_wide_sorted['Sıralama_2023'].astype(int)
df_wide_sorted['Sıralama_2024'] = df_wide_sorted['Sıralama_2024'].astype(int)
# Out:
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\3658233354.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted['Sıralama_2021'] = df_wide_sorted['Sıralama_2021'].astype(int)
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\3658233354.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted['Sıralama_2022'] = df_wide_sorted['Sıralama_2022'].astype(int)
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\3658233354.py:3: SettingWithCopyWarning:
# ...

# %%
df_wide_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 16267 to 8218
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Bölüm           2000 non-null   object
#  1   Üniversite      2000 non-null   object
#  2   UniKodu         2000 non-null   int64
#  3   PuanTürü        2000 non-null   object
#  4   Kontenjan_2021  2000 non-null   object
#  5   Kontenjan_2022  2000 non-null   object
#  6   Kontenjan_2023  2000 non-null   object
#  7   Kontenjan_2024  2000 non-null   object
#  8   Sıralama_2021   2000 non-null   int64
#  9   Sıralama_2022   2000 non-null   int64
#  10  Sıralama_2023   2000 non-null   int64
#  11  Sıralama_2024   2000 non-null   int64
#  12  TabanPuan_2021  2000 non-null   float64
#  13  TabanPuan_2022  2000 non-null   float64
#  14  TabanPuan_2023  2000 non-null   float64
#  15  TabanPuan_2024  2000 non-null   float64
# dtypes: float64(4), int64(5), object(7)
# ...

# %%
def kontenjan_to_int(k):
    try:
        return sum(int(x) for x in k.split('+'))
    except:
        return 0

for year in ['2021','2022','2023','2024']:
    df_wide_sorted[f'Kontenjan_{year}_num'] = df_wide_sorted[f'Kontenjan_{year}'].apply(kontenjan_to_int)
# Out:
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\1428156478.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted[f'Kontenjan_{year}_num'] = df_wide_sorted[f'Kontenjan_{year}'].apply(kontenjan_to_int)
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\1428156478.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted[f'Kontenjan_{year}_num'] = df_wide_sorted[f'Kontenjan_{year}'].apply(kontenjan_to_int)
# ...

# %%
df_wide_sorted
# Out:
#                                            Bölüm  \
# 16267                                       Tıp
# 16379                                       Tıp
# 1854                    Bilgisayar Mühendisliği
# 16181                                       Tıp
# 5922                                      Fizik
# ...                                          ...
# 17069           Yapay Zeka ve Veri Mühendisliği
# 15408                       Türkçe Öğretmenliği
# 6464   Gastronomi ve Mutfak Sanatları (Fakülte)
# 2901                            Biyomühendislik
# 8218                                      Hukuk
#
#                                               Üniversite    UniKodu PuanTürü  \
# 16267                          Koç Üniversitesi (Burslu)  203910699      SAY
# 16379             İstanbul Medipol Üniversitesi (Burslu)  203110477      SAY
# 1854                           Koç Üniversitesi (Burslu)  203910363      SAY
# ...

# %%
df_wide_sorted.isna().sum()
# Out:
# Bölüm                 0
# Üniversite            0
# UniKodu               0
# PuanTürü              0
# Kontenjan_2021        0
# Kontenjan_2022        0
# Kontenjan_2023        0
# Kontenjan_2024        0
# Sıralama_2021         0
# Sıralama_2022         0
# Sıralama_2023         0
# Sıralama_2024         0
# TabanPuan_2021        0
# TabanPuan_2022        0
# TabanPuan_2023        0
# TabanPuan_2024        0
# Kontenjan_2021_num    0
# Kontenjan_2022_num    0
# Kontenjan_2023_num    0
# Kontenjan_2024_num    0
# dtype: int64

# %%
# NaN yerine 0 koymak
df_wide_sorted.fillna(0, inplace=True)

# %%
df_wide_sorted.drop(axis=1,columns = ['Kontenjan_2021','Kontenjan_2022','Kontenjan_2023','Kontenjan_2024'], inplace=True)
# Out:
# C:\Users\E-SPOR\AppData\Local\Temp\ipykernel_20412\186985845.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_wide_sorted.drop(axis=1,columns = ['Kontenjan_2021','Kontenjan_2022','Kontenjan_2023','Kontenjan_2024'], inplace=True)

# %%
df_wide_sorted
# Out:
#                                            Bölüm  \
# 16267                                       Tıp
# 16379                                       Tıp
# 1854                    Bilgisayar Mühendisliği
# 16181                                       Tıp
# 5922                                      Fizik
# ...                                          ...
# 17069           Yapay Zeka ve Veri Mühendisliği
# 15408                       Türkçe Öğretmenliği
# 6464   Gastronomi ve Mutfak Sanatları (Fakülte)
# 2901                            Biyomühendislik
# 8218                                      Hukuk
#
#                                               Üniversite    UniKodu PuanTürü  \
# 16267                          Koç Üniversitesi (Burslu)  203910699      SAY
# 16379             İstanbul Medipol Üniversitesi (Burslu)  203110477      SAY
# 1854                           Koç Üniversitesi (Burslu)  203910363      SAY
# ...

# %%
df_wide_sorted.to_json(r"C:\Users\E-SPOR\Desktop\egitim2\egitim2\scripts\üniler\üniler.json", orient='records', force_ascii=False)

# %%
df_wide_sorted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2000 entries, 16267 to 8218
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Bölüm               2000 non-null   object
#  1   Üniversite          2000 non-null   object
#  2   UniKodu             2000 non-null   int64
#  3   PuanTürü            2000 non-null   object
#  4   Sıralama_2021       2000 non-null   int64
#  5   Sıralama_2022       2000 non-null   int64
#  6   Sıralama_2023       2000 non-null   int64
#  7   Sıralama_2024       2000 non-null   int64
#  8   TabanPuan_2021      2000 non-null   float64
#  9   TabanPuan_2022      2000 non-null   float64
#  10  TabanPuan_2023      2000 non-null   float64
#  11  TabanPuan_2024      2000 non-null   float64
#  12  Kontenjan_2021_num  2000 non-null   int64
#  13  Kontenjan_2022_num  2000 non-null   int64
#  14  Kontenjan_2023_num  2000 non-null   int64
# ...
